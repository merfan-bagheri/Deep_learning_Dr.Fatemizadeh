# %%
# Feel free to import any other libraries and modules.
import numpy as np
import matplotlib.pyplot as plt
import torch
from torchvision import datasets, transforms
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
from torch import nn

# %% [markdown]
# # Part One: Optimization Algorithms
# ## 1. Gradient Descent
# The Gradient Descent (GD) algorithm finds the minimum of a given
# function by taking small steps along the function's gradient:
#
# >$\Theta \leftarrow \Theta_0$
#
# >**while** stop condition not met **do**
#
# >$~~~~\Theta \leftarrow \Theta - \alpha \nabla_\Theta f(\Theta)$
#
# >**end while**
#
# where $f$ is the function to minimize, $\nabla_\Theta f(\Theta)$
# denotes $f$'s gradient at $\Theta$ and $\alpha$ is the learning rate.
#
# **Task1:** Implement the GD algorithm as a function:
#
#   \begin{equation}
#       \Theta_{opt} = \text{GD}(f, \Theta_0, \alpha, \rho)
#   \end{equation}
# where $f$ is a function returning the cost and its gradient with respect to parameter vector $\Theta$, $\Theta_0$ is the initial value, and $\alpha$
# is the learning rate. You can assume that $\alpha$. remains constant during the optimization. $\rho$ is stop condition. \\
# Then, use the GD algorithm to find the optimum of the [Rosenbrock function](https://en.wikipedia.org/wiki/Rosenbrock_function) (Consider $a=1, b=100$).
#  \\
# Also, plot the values found by GD at subsequent iterations.
#
# ## 2. Newton's Method
# Newton's method is an iterative optimization algorithm used to find the minimum of a function.
# The basic update step in Newton's method is given by:
#
# \begin{equation}
# \Theta = \Theta - H^{-1} \cdot \nabla f(\Theta)
# \end{equation}
#
#
# Where  $ H $ is the Hessian matrix of the function at $ \Theta $, and $ H^{-1} $ is the inverse of the Hessian matrix, used to adjust the step size and direction more accurately than just using the gradient alone (as done in gradient descent).
#
# #### Line Search
# Sometimes, Newton's method may take too large of a step, which can lead to divergence. To prevent this, a simple **line search** is used. This reduces the step size $ \alpha $ if the function value doesn't improve after the step.
#
# Steps:
# 1. Compute the gradient and Hessian matrix at the current point.
# 2. Calculate the step direction by multiplying the inverse of the Hessian with the gradient.
# 3. Update the point by subtracting the step from the current point.
# 4. If the function value doesn't improve, reduce the step size $ \alpha $.
# 5. Repeat until the gradient becomes sufficiently small (close to zero), indicating convergence.
#
#
#
# **Task2:** Implement Newton's method and compare it with the gradient descent. You will also need to implement a line search alogithm, e.g. (https://en.wikipedia.org/wiki/Backtracking_line_search) and make sure that the Newton's direction is indeed one along which the function is minimized.

# %%
def rosenbrock(x):
    """Returns the value and gradient of Rosenbrock's function at x: 2d vector"""
    a, b = 1, 100
    val = (a-x[0])**2 + b*(x[1]-x[0]**2)**2
    dv_dx0 = -2*(a-x[0]) -2*x[0]*(2*b*(x[1]-x[0]**2))
    dv_dx1 = 2*b*(x[1]-x[0]**2)
    grad = np.array([dv_dx0, dv_dx1])

    return val, grad

def rosenbrock_hessian(x):
    """Returns the value, gradient and hessian of Rosenbrock's function at x: 2d vector"""
    val, grad = rosenbrock(x)
    a, b = 1, 100
    # Hessian matrix components
    d2v_dx0x0 = 2 -4*b*x[1] +12*b*x[0]**2
    d2v_dx0x1 = -4*b*x[0]
    d2v_dx1x0 = -4*b*x[0]
    d2v_dx1x1 = 2*b

    # Hessian matrix
    hessian = np.array([[d2v_dx0x0, d2v_dx0x1],
                [d2v_dx1x0, d2v_dx1x1]])

    return val, grad, hessian


def GD(f, theta0, alpha, stop_tolerance=1e-10, max_steps=1000000):
    """Runs gradient descent algorithm on f.

    Args:
        f: function that when evaluated on a Theta of same dtype and shape as Theta0
            returns a tuple (value, dv_dtheta) with dValuedTheta of the same shape
            as Theta
        theta0: starting point
        alpha: step length
        stop_tolerance: stop iterations when improvement is below this threshold
        max_steps: maximum number of steps
    Returns:
        tuple:
        - theta: optimum theta found by the algorithm
        - history: list of length num_steps containing tuples (theta, (val, dv_dtheta: np.array))

    """
    history = []

    theta = theta0

    step = 0
    while step < max_steps:
        val, grad = f(theta)
        improvement = alpha * grad
        theta = theta - improvement
        history.append([theta.copy(), val, grad.copy()])
        step = step + 1
        if np.linalg.norm(improvement) <= stop_tolerance:
            break

    return theta, history

# %%
# Find the optimum of rosenbrock function

X0 = [0.,2.]
Xopt, Xhist = GD(rosenbrock, X0, alpha=1e-3, stop_tolerance=1e-10, max_steps=1e6)

print ("Found optimum at %s in %d steps (true minimum is at [1,1])" % (Xopt, len(Xhist)))

# Plot how the value changes over iterations
values = [v[1] for v in Xhist]
plt.plot(values)
plt.yscale('log')
plt.xscale('log')
plt.xlabel('Iteration')
plt.ylabel('Log of Rosenbrock Function Value')
plt.title('Convergence of Gradient Descent on Rosenbrock Function (Log Scale)')
plt.grid(True)
plt.show()
# Out:
# Found optimum at [0.99999989 0.99999978] in 37027 steps (true minimum is at [1,1])

# %%
# Newton's Method
def Newton(f, theta0, alpha=1, stop_tolerance=1e-10, max_steps=1000000):
    """Performs Newton's optimization method with a simple line search.

    Args:
        f: function that when evaluated on a Theta of same dtype and shape as Theta0
            returns a tuple (value, gradient, hessian), where gradient and Hessian
            have the same shape as Theta.
        theta0: starting point.
        alpha: step length for backtracking line search (default is 1).
        stop_tolerance: stop iterations when the norm of the gradient is below this threshold.
        max_steps: maximum number of iterations.
    Returns:
        tuple:
        - theta: optimal Theta after convergence or maximum steps.
        - history: list of tuples (theta, value, gradient) containing the optimization path.
    """
    history = []
    theta = theta0
    c, tau = 1e-5, 0.9
    step = 0

    while step < max_steps:
        while True:
            val, grad, hessian = f(theta)
            improvement = alpha * np.linalg.inv(hessian) @ grad
            theta_n = theta - improvement
            val_n = f(theta_n)[0]
            if val - val_n > alpha * c * np.dot(improvement, grad):
                break
            alpha *= tau
        theta -= improvement
        history.append([theta.copy(), val, grad.copy(), hessian.copy()])
        step += 1
        if np.linalg.norm(improvement) <= stop_tolerance:
            break

    return theta, history

# Test Newton's method on the Rosenbrock function
X0 = [0., 2.]  # Initial guess
Xopt, Xhist = Newton(rosenbrock_hessian, X0)

print ("Found optimum at %s in %d steps (true minimum is at [1,1])" % (Xopt, len(Xhist)))

# Plot how the value changes over iterations
values = [v[1] for v in Xhist]
plt.plot(values)
plt.yscale('log')
# plt.xscale('log')
plt.xlabel('Iteration')
plt.ylabel('Log of Rosenbrock Function Value')
plt.title('Convergence of Newton\'s Method on Rosenbrock Function (Log Scale)')
plt.grid(True)
plt.show()
# Out:
# Found optimum at [1. 1.] in 96 steps (true minimum is at [1,1])

# %% [markdown]
# # Part two: MLP for MNIST Classification
# In this part, we are going to use `PyTorch`. If you want to become more familiar with it, check this resource: https://www.learnpytorch.io/
#
# #### In this homework, you need to
# - implement SGD optimizer (`./optimizer.py`)
# - implement forward and backward for FCLayer (`layers.py`)
# - implement forward and backward for SigmoidLayer (`layers.py`)
# - implement forward and backward for ReLULayer (`layers.py`)
# - implement forward and backward for DropoutLayer (`layers.py`)
# - implement train and test process (`solver.py`)

# %%
from layers import FCLayer, SigmoidLayer, ReLULayer
from solver import train, test
from optimizer import SGD

# %%
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cpu'

# %%
# Load MNIST dataset

# Converts PIL image to tensor and scales to [0, 1] and flatten it
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Lambda(lambda x: x.view(-1)),
])

# Load MNIST dataset with the defined transform
train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

# One-hot encoding for labels
def decode_label(label, num_classes=10):
    return torch.nn.functional.one_hot(torch.tensor(label), num_classes=num_classes).float()

# Preprocess labels and combine with transformed images
y_train = [decode_label(label) for _, label in train_dataset]
y_test = [decode_label(label) for _, label in test_dataset]

# Convert the data into tensor datasets for training and testing
train_dataset = TensorDataset(torch.stack([img for img, _ in train_dataset]), torch.stack(y_train))
test_dataset = TensorDataset(torch.stack([img for img, _ in test_dataset]), torch.stack(y_test))

# Create data loaders
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
num_epoch = 20

criterion = nn.MSELoss()

# Build MLP with FCLayer and SigmoidLayer you've implemented in layers.py
sigmoidMLP = nn.Sequential(
    FCLayer(784, 128),
    SigmoidLayer(),
    FCLayer(128, 10)
)

# Initialize optimizer you've implemented in optimizer.py
sgd = SGD(params=sigmoidMLP.parameters(), learning_rate=0.01)

# Train the model using train function you've implemented in solver.py
sigmoidMLP = train(sigmoidMLP, criterion, sgd, train_dataloader, num_epoch, device=device)
# Out:
# Epoch [0] Average training loss: 0.0771, Average training accuracy: 0.4956
# Epoch [1] Average training loss: 0.0556, Average training accuracy: 0.7378
# Epoch [2] Average training loss: 0.0506, Average training accuracy: 0.7835
# Epoch [3] Average training loss: 0.0482, Average training accuracy: 0.8046
# Epoch [4] Average training loss: 0.0466, Average training accuracy: 0.8173
# Epoch [5] Average training loss: 0.0456, Average training accuracy: 0.8254
# Epoch [6] Average training loss: 0.0448, Average training accuracy: 0.8307
# Epoch [7] Average training loss: 0.0442, Average training accuracy: 0.8344
# Epoch [8] Average training loss: 0.0437, Average training accuracy: 0.8384
# Epoch [9] Average training loss: 0.0432, Average training accuracy: 0.8408
# Epoch [10] Average training loss: 0.0429, Average training accuracy: 0.8430
# Epoch [11] Average training loss: 0.0426, Average training accuracy: 0.8455
# Epoch [12] Average training loss: 0.0423, Average training accuracy: 0.8465
# Epoch [13] Average training loss: 0.0420, Average training accuracy: 0.8474
# Epoch [14] Average training loss: 0.0418, Average training accuracy: 0.8489
# Epoch [15] Average training loss: 0.0415, Average training accuracy: 0.8504
# Epoch [16] Average training loss: 0.0413, Average training accuracy: 0.8517
# Epoch [17] Average training loss: 0.0411, Average training accuracy: 0.8514
# Epoch [18] Average training loss: 0.0409, Average training accuracy: 0.8529
# Epoch [19] Average training loss: 0.0407, Average training accuracy: 0.8533

# %%
# Test your model using test function you've implemented in solver.py
test(sigmoidMLP, test_dataloader, device)
# Out:
# The test accuracy is 0.8627.

# %%
# Build MLP with FCLayer and ReLULayer
reluMLP = nn.Sequential(
    FCLayer(784, 128),
    ReLULayer(),
    FCLayer(128, 10)
)

# Initialize optimizer
sgd = SGD(reluMLP.parameters(), learning_rate=0.01)

# Train the model
reluMLP = train(reluMLP, criterion, sgd, train_dataloader, num_epoch, device=device)
# Out:
# Epoch [0] Average training loss: 0.0712, Average training accuracy: 0.6373
# Epoch [1] Average training loss: 0.0467, Average training accuracy: 0.8230
# Epoch [2] Average training loss: 0.0399, Average training accuracy: 0.8589
# Epoch [3] Average training loss: 0.0357, Average training accuracy: 0.8765
# Epoch [4] Average training loss: 0.0327, Average training accuracy: 0.8875
# Epoch [5] Average training loss: 0.0305, Average training accuracy: 0.8953
# Epoch [6] Average training loss: 0.0288, Average training accuracy: 0.9011
# Epoch [7] Average training loss: 0.0274, Average training accuracy: 0.9060
# Epoch [8] Average training loss: 0.0262, Average training accuracy: 0.9102
# Epoch [9] Average training loss: 0.0253, Average training accuracy: 0.9130
# Epoch [10] Average training loss: 0.0244, Average training accuracy: 0.9162
# Epoch [11] Average training loss: 0.0237, Average training accuracy: 0.9185
# Epoch [12] Average training loss: 0.0231, Average training accuracy: 0.9205
# Epoch [13] Average training loss: 0.0225, Average training accuracy: 0.9227
# Epoch [14] Average training loss: 0.0220, Average training accuracy: 0.9247
# Epoch [15] Average training loss: 0.0215, Average training accuracy: 0.9264
# Epoch [16] Average training loss: 0.0211, Average training accuracy: 0.9279
# Epoch [17] Average training loss: 0.0207, Average training accuracy: 0.9288
# Epoch [18] Average training loss: 0.0204, Average training accuracy: 0.9297
# Epoch [19] Average training loss: 0.0200, Average training accuracy: 0.9309

# %%
# Test the model
test(reluMLP, test_dataloader, device)
# Out:
# The test accuracy is 0.9313.

# %%
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, TensorDataset, Subset

# Set the alpha value for reduction (between 0 and 1)
alpha = 0.005  # Example value

# Define the transform to convert PIL images to tensors and flatten them
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Lambda(lambda x: x.view(-1)),  # Flatten the image
])

# Load the MNIST dataset with the defined transform
train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

# One-hot encoding for labels
def decode_label(label, num_classes=10):
    return torch.nn.functional.one_hot(torch.tensor(label), num_classes=num_classes).float()

# Preprocess labels and combine with transformed images
y_train = [decode_label(label) for _, label in train_dataset]
y_test = [decode_label(label) for _, label in test_dataset]

# Convert the data into tensor datasets for training and testing
train_dataset = TensorDataset(torch.stack([img for img, _ in train_dataset]), torch.stack(y_train))
test_dataset = TensorDataset(torch.stack([img for img, _ in test_dataset]), torch.stack(y_test))

# Calculate the number of samples to keep based on alpha
num_samples = int(len(train_dataset) * alpha)

# Randomly sample indices
indices = torch.randperm(len(train_dataset))[:num_samples]

# Create a reduced dataset
reduced_train_dataset = Subset(train_dataset, indices)

# Create data loaders
train_dataloader = DataLoader(reduced_train_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Print the sizes of the datasets
print(f"Original training dataset size: {len(train_dataset)}")
print(f"Reduced training dataset size (alpha={alpha}): {len(reduced_train_dataset)}")
print(f"Test dataset size: {len(test_dataset)}")
# Out:
# Original training dataset size: 60000
# Reduced training dataset size (alpha=0.005): 300
# Test dataset size: 10000

# %% [markdown]
# ### Overfit the model
# Try to overfit the reluMLP model. You can make the model as complex as you like, use subset of the data for training or any other approach you want.
# Then add **DropoutLayer** to your model in order to reduce overfitting problem.

# %%
#TODO: overfit the reluMLP model
# Overfit on the model with reduce the Dataset length to 300 training samples and make the network deeper and more complex
# Build MLP with FCLayer and ReLULayer
reluMLP = nn.Sequential(
    FCLayer(784, 512),
    ReLULayer(),
    FCLayer(512, 256),
    ReLULayer(),
    FCLayer(256, 32),
    ReLULayer(),
    FCLayer(32, 10)
)

# Initialize optimizer
num_epoch = 50
sgd = SGD(reluMLP.parameters(), learning_rate=0.5)

# Train the model, The training accuracy is 100%
reluMLP = train(reluMLP, criterion, sgd, train_dataloader, num_epoch, device=device)
# Out:
# Epoch [0] Average training loss: 0.1092, Average training accuracy: 0.2031
# Epoch [1] Average training loss: 0.0764, Average training accuracy: 0.4396
# Epoch [2] Average training loss: 0.0677, Average training accuracy: 0.6281
# Epoch [3] Average training loss: 0.0618, Average training accuracy: 0.6635
# Epoch [4] Average training loss: 0.0530, Average training accuracy: 0.8052
# Epoch [5] Average training loss: 0.0484, Average training accuracy: 0.8260
# Epoch [6] Average training loss: 0.0436, Average training accuracy: 0.8729
# Epoch [7] Average training loss: 0.0392, Average training accuracy: 0.8708
# Epoch [8] Average training loss: 0.0356, Average training accuracy: 0.9229
# Epoch [9] Average training loss: 0.0320, Average training accuracy: 0.9531
# Epoch [10] Average training loss: 0.0294, Average training accuracy: 0.9396
# Epoch [11] Average training loss: 0.0284, Average training accuracy: 0.9437
# Epoch [12] Average training loss: 0.0246, Average training accuracy: 0.9719
# Epoch [13] Average training loss: 0.0240, Average training accuracy: 0.9812
# Epoch [14] Average training loss: 0.0206, Average training accuracy: 0.9781
# Epoch [15] Average training loss: 0.0191, Average training accuracy: 0.9760
# Epoch [16] Average training loss: 0.0166, Average training accuracy: 0.9906
# Epoch [17] Average training loss: 0.0164, Average training accuracy: 0.9875
# Epoch [18] Average training loss: 0.0125, Average training accuracy: 0.9938
# Epoch [19] Average training loss: 0.0140, Average training accuracy: 0.9938
# Epoch [20] Average training loss: 0.0119, Average training accuracy: 0.9969
# Epoch [21] Average training loss: 0.0103, Average training accuracy: 0.9938
# Epoch [22] Average training loss: 0.0100, Average training accuracy: 0.9969
# Epoch [23] Average training loss: 0.0077, Average training accuracy: 1.0000
# Epoch [24] Average training loss: 0.0072, Average training accuracy: 1.0000
# Epoch [25] Average training loss: 0.0068, Average training accuracy: 1.0000
# Epoch [26] Average training loss: 0.0067, Average training accuracy: 1.0000
# Epoch [27] Average training loss: 0.0060, Average training accuracy: 1.0000
# Epoch [28] Average training loss: 0.0052, Average training accuracy: 1.0000
# Epoch [29] Average training loss: 0.0043, Average training accuracy: 1.0000
# Epoch [30] Average training loss: 0.0041, Average training accuracy: 1.0000
# Epoch [31] Average training loss: 0.0042, Average training accuracy: 1.0000
# Epoch [32] Average training loss: 0.0035, Average training accuracy: 1.0000
# Epoch [33] Average training loss: 0.0036, Average training accuracy: 1.0000
# Epoch [34] Average training loss: 0.0032, Average training accuracy: 1.0000
# Epoch [35] Average training loss: 0.0026, Average training accuracy: 1.0000
# Epoch [36] Average training loss: 0.0026, Average training accuracy: 1.0000
# Epoch [37] Average training loss: 0.0024, Average training accuracy: 1.0000
# Epoch [38] Average training loss: 0.0023, Average training accuracy: 1.0000
# Epoch [39] Average training loss: 0.0022, Average training accuracy: 1.0000
# Epoch [40] Average training loss: 0.0021, Average training accuracy: 1.0000
# Epoch [41] Average training loss: 0.0018, Average training accuracy: 1.0000
# Epoch [42] Average training loss: 0.0016, Average training accuracy: 1.0000
# Epoch [43] Average training loss: 0.0017, Average training accuracy: 1.0000
# Epoch [44] Average training loss: 0.0014, Average training accuracy: 1.0000
# Epoch [45] Average training loss: 0.0014, Average training accuracy: 1.0000
# Epoch [46] Average training loss: 0.0013, Average training accuracy: 1.0000
# Epoch [47] Average training loss: 0.0014, Average training accuracy: 1.0000
# Epoch [48] Average training loss: 0.0012, Average training accuracy: 1.0000
# Epoch [49] Average training loss: 0.0013, Average training accuracy: 1.0000

# %%
# Test the model
test(reluMLP, test_dataloader, device)
# Out:
# The test accuracy is 0.8247.

# %%
from layers import DropoutLayer

#TODO: add DropoutLayer to your model
# Define your model with Dropout
reluMLP = nn.Sequential(
    FCLayer(784, 512),
    ReLULayer(),
    DropoutLayer(0.5),  # Add Dropout layer with 50% drop probability
    FCLayer(512, 256),
    ReLULayer(),
    # DropoutLayer(0.02),  # Add Dropout layer with 50% drop probability
    FCLayer(256, 32),
    ReLULayer(),
    FCLayer(32, 10)
)

# %%
# Initialize optimizer
sgd = SGD(reluMLP.parameters(), learning_rate=0.5)

# Train the model
reluMLP = train(reluMLP, criterion, sgd, train_dataloader, num_epoch, device=device)
# Out:
# Epoch [0] Average training loss: 0.1121, Average training accuracy: 0.1500
# Epoch [1] Average training loss: 0.0895, Average training accuracy: 0.2396
# Epoch [2] Average training loss: 0.0858, Average training accuracy: 0.2833
# Epoch [3] Average training loss: 0.0815, Average training accuracy: 0.3948
# Epoch [4] Average training loss: 0.0774, Average training accuracy: 0.4677
# Epoch [5] Average training loss: 0.0753, Average training accuracy: 0.4865
# Epoch [6] Average training loss: 0.0713, Average training accuracy: 0.5333
# Epoch [7] Average training loss: 0.0677, Average training accuracy: 0.5635
# Epoch [8] Average training loss: 0.0632, Average training accuracy: 0.6708
# Epoch [9] Average training loss: 0.0603, Average training accuracy: 0.6854
# Epoch [10] Average training loss: 0.0555, Average training accuracy: 0.7604
# Epoch [11] Average training loss: 0.0543, Average training accuracy: 0.7312
# Epoch [12] Average training loss: 0.0507, Average training accuracy: 0.7677
# Epoch [13] Average training loss: 0.0465, Average training accuracy: 0.8146
# Epoch [14] Average training loss: 0.0461, Average training accuracy: 0.8094
# Epoch [15] Average training loss: 0.0409, Average training accuracy: 0.8240
# Epoch [16] Average training loss: 0.0410, Average training accuracy: 0.8594
# Epoch [17] Average training loss: 0.0382, Average training accuracy: 0.8812
# Epoch [18] Average training loss: 0.0359, Average training accuracy: 0.9000
# Epoch [19] Average training loss: 0.0351, Average training accuracy: 0.8833
# Epoch [20] Average training loss: 0.0331, Average training accuracy: 0.9250
# Epoch [21] Average training loss: 0.0322, Average training accuracy: 0.9010
# Epoch [22] Average training loss: 0.0298, Average training accuracy: 0.9167
# Epoch [23] Average training loss: 0.0289, Average training accuracy: 0.9437
# Epoch [24] Average training loss: 0.0269, Average training accuracy: 0.9479
# Epoch [25] Average training loss: 0.0261, Average training accuracy: 0.9531
# Epoch [26] Average training loss: 0.0254, Average training accuracy: 0.9625
# Epoch [27] Average training loss: 0.0237, Average training accuracy: 0.9594
# Epoch [28] Average training loss: 0.0236, Average training accuracy: 0.9656
# Epoch [29] Average training loss: 0.0212, Average training accuracy: 0.9573
# Epoch [30] Average training loss: 0.0213, Average training accuracy: 0.9781
# Epoch [31] Average training loss: 0.0197, Average training accuracy: 0.9781
# Epoch [32] Average training loss: 0.0202, Average training accuracy: 0.9656
# Epoch [33] Average training loss: 0.0185, Average training accuracy: 0.9812
# Epoch [34] Average training loss: 0.0165, Average training accuracy: 0.9938
# Epoch [35] Average training loss: 0.0166, Average training accuracy: 0.9938
# Epoch [36] Average training loss: 0.0160, Average training accuracy: 0.9969
# Epoch [37] Average training loss: 0.0160, Average training accuracy: 0.9906
# Epoch [38] Average training loss: 0.0150, Average training accuracy: 0.9969
# Epoch [39] Average training loss: 0.0146, Average training accuracy: 0.9938
# Epoch [40] Average training loss: 0.0150, Average training accuracy: 0.9969
# Epoch [41] Average training loss: 0.0131, Average training accuracy: 1.0000
# Epoch [42] Average training loss: 0.0128, Average training accuracy: 1.0000
# Epoch [43] Average training loss: 0.0125, Average training accuracy: 0.9875
# Epoch [44] Average training loss: 0.0117, Average training accuracy: 0.9969
# Epoch [45] Average training loss: 0.0128, Average training accuracy: 0.9969
# Epoch [46] Average training loss: 0.0118, Average training accuracy: 0.9969
# Epoch [47] Average training loss: 0.0111, Average training accuracy: 0.9969
# Epoch [48] Average training loss: 0.0113, Average training accuracy: 1.0000
# Epoch [49] Average training loss: 0.0106, Average training accuracy: 1.0000

# %%
# Test the model, Accuracy is better than the model without dropout layer
test(reluMLP, test_dataloader, device)
# Out:
# The test accuracy is 0.8465.
